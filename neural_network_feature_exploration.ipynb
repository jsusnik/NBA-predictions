# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas
from keras import models
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
from google.colab import drive
drive.mount('/content/drive')

root_path = 'drive/MyDrive/NBA-predictions'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Neural Network Model 1:
#
# This model will ONLY use the last 5 games' average stats, while knowing nothing about who the teams are, to try and predict the winner.

# %%
train_data = pd.read_csv(root_path +'/data/train_data_ppmadf.csv')
test_data= pd.read_csv(root_path +'/data/test_data_ppmadf.csv')

X_train = train_data.drop(columns=['HOME_WIN'])
y_train = train_data['HOME_WIN']

X_test = test_data.drop(columns=['HOME_WIN'])
y_test = test_data['HOME_WIN']

# %%
cols_to_drop = [
                'AWAY_RA_AST',
                'HOME_RA_AST',
                'AWAY_RA_BLK',
                'HOME_RA_BLK',
                'AWAY_RA_DREB',
                'HOME_RA_DREB',
                'AWAY_RA_FG3A',
                'HOME_RA_FG3A',
                'AWAY_RA_FGA',
                'HOME_RA_FGA',
                'AWAY_RA_FGM',
                'HOME_RA_FGM',
                'AWAY_RA_FG3M',
                'HOME_RA_FG3M',
                'AWAY_RA_OREB',
                'HOME_RA_OREB',
                'AWAY_RA_FTA',
                'HOME_RA_FTA',
                'AWAY_RA_FTM',
                'HOME_RA_FTM',
                'AWAY_RA_PF',
                'HOME_RA_PF',
]

# drop the team abbreviation columns for both HOME and AWAY teams
# for i in X_train.columns[:60]:
#   cols_to_drop.append(i)

X_train_revised = X_train.drop(columns=cols_to_drop)
X_test_revised = X_test.drop(columns=cols_to_drop)

# %%
X_train_revised
# Out:
#       ATL  BKN  BOS  CHA  ...  HOME_RA_PTS  HOME_RA_REB  HOME_RA_STL  HOME_RA_TOV
# 0       0    0    0    0  ...     0.346491     0.536232     0.275862     0.636364
# 1       0    1    0    0  ...     0.429825     0.442029     0.448276     0.610390
# 2       0    0    0    0  ...     0.377193     0.528986     0.327586     0.506494
# 3       0    0    0    0  ...     0.399123     0.521739     0.310345     0.441558
# 4       0    0    0    0  ...     0.381579     0.507246     0.379310     0.545455
# ...   ...  ...  ...  ...  ...          ...          ...          ...          ...
# 2391    0    0    0    0  ...     0.407895     0.528986     0.362069     0.467532
# 2392    0    0    0    1  ...     0.289474     0.420290     0.241379     0.285714
# 2393    0    0    0    1  ...     0.548246     0.514493     0.103448     0.220779
# 2394    0    0    0    0  ...     0.434211     0.710145     0.396552     0.259740
# 2395    0    0    0    1  ...     0.342105     0.623188     0.189655     0.454545
#
# [2396 rows x 76 columns]

# %%
# create model
model = Sequential()
model.add(Dense(152, input_dim=76, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(76, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(28, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callbacks = [EarlyStopping(
    monitor='val_loss', min_delta=0, patience=5000, verbose=1,
    mode='auto', baseline=None, restore_best_weights=True
),
ModelCheckpoint(
    filepath=(root_path + '/data/neural_network_checkpoint_2'),
    monitor='val_accuracy',
    mode='auto',
    save_best_only=True)
]

# %%
history = model.fit(X_train_revised, y_train, validation_data=(X_test_revised, y_test), batch_size=5, epochs=250, 
                    #steps_per_epoch=60, 
                    verbose=1, callbacks=callbacks)
# Out:
# Epoch 1/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.6565 - accuracy: 0.6035 - val_loss: 0.6728 - val_accuracy: 0.6049
# INFO:tensorflow:Assets written to: drive/MyDrive/NBA-predictions/data/neural_network_checkpoint_2/assets
# Epoch 2/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.6063 - accuracy: 0.6665 - val_loss: 0.6236 - val_accuracy: 0.6447
# INFO:tensorflow:Assets written to: drive/MyDrive/NBA-predictions/data/neural_network_checkpoint_2/assets
# Epoch 3/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.5956 - accuracy: 0.6703 - val_loss: 0.6141 - val_accuracy: 0.6496
# INFO:tensorflow:Assets written to: drive/MyDrive/NBA-predictions/data/neural_network_checkpoint_2/assets
# Epoch 4/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.5843 - accuracy: 0.6757 - val_loss: 0.6226 - val_accuracy: 0.6520
# INFO:tensorflow:Assets written to: drive/MyDrive/NBA-predictions/data/neural_network_checkpoint_2/assets
# Epoch 5/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.5775 - accuracy: 0.6799 - val_loss: 0.6298 - val_accuracy: 0.6561
# INFO:tensorflow:Assets written to: drive/MyDrive/NBA-predictions/data/neural_network_checkpoint_2/assets
# Epoch 6/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.5706 - accuracy: 0.6882 - val_loss: 0.6204 - val_accuracy: 0.6439
# Epoch 7/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.5578 - accuracy: 0.6999 - val_loss: 0.6208 - val_accuracy: 0.6431
# Epoch 8/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.5540 - accuracy: 0.6978 - val_loss: 0.6379 - val_accuracy: 0.6496
# Epoch 9/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.5338 - accuracy: 0.7229 - val_loss: 0.6374 - val_accuracy: 0.6390
# Epoch 10/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.5267 - accuracy: 0.7229 - val_loss: 0.6476 - val_accuracy: 0.6463
# Epoch 11/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.5139 - accuracy: 0.7237 - val_loss: 0.6863 - val_accuracy: 0.6463
# Epoch 12/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.4915 - accuracy: 0.7437 - val_loss: 0.7370 - val_accuracy: 0.6447
# Epoch 13/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.4879 - accuracy: 0.7412 - val_loss: 0.6891 - val_accuracy: 0.6512
# Epoch 14/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.4710 - accuracy: 0.7483 - val_loss: 0.7071 - val_accuracy: 0.6439
# Epoch 15/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.4664 - accuracy: 0.7617 - val_loss: 0.6880 - val_accuracy: 0.6512
# Epoch 16/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.4490 - accuracy: 0.7638 - val_loss: 0.7469 - val_accuracy: 0.6374
# Epoch 17/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.4316 - accuracy: 0.7717 - val_loss: 0.8438 - val_accuracy: 0.6455
# Epoch 18/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.4215 - accuracy: 0.7855 - val_loss: 0.8293 - val_accuracy: 0.6407
# Epoch 19/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.4171 - accuracy: 0.7884 - val_loss: 0.7334 - val_accuracy: 0.6415
# Epoch 20/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3985 - accuracy: 0.7976 - val_loss: 0.7816 - val_accuracy: 0.6293
# Epoch 21/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.4024 - accuracy: 0.7967 - val_loss: 0.8308 - val_accuracy: 0.6325
# Epoch 22/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3854 - accuracy: 0.8013 - val_loss: 1.0124 - val_accuracy: 0.6390
# Epoch 23/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3797 - accuracy: 0.8047 - val_loss: 1.0154 - val_accuracy: 0.6285
# Epoch 24/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3700 - accuracy: 0.8151 - val_loss: 1.0379 - val_accuracy: 0.6472
# Epoch 25/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3478 - accuracy: 0.8301 - val_loss: 1.0445 - val_accuracy: 0.6366
# Epoch 26/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3590 - accuracy: 0.8264 - val_loss: 0.8994 - val_accuracy: 0.6260
# Epoch 27/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3492 - accuracy: 0.8301 - val_loss: 1.1195 - val_accuracy: 0.6455
# Epoch 28/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3348 - accuracy: 0.8322 - val_loss: 1.1878 - val_accuracy: 0.6276
# Epoch 29/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3319 - accuracy: 0.8418 - val_loss: 1.1372 - val_accuracy: 0.6293
# Epoch 30/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3300 - accuracy: 0.8368 - val_loss: 1.0524 - val_accuracy: 0.6228
# Epoch 31/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3240 - accuracy: 0.8410 - val_loss: 1.1915 - val_accuracy: 0.6317
# Epoch 32/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3275 - accuracy: 0.8322 - val_loss: 1.1555 - val_accuracy: 0.6350
# Epoch 33/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.3067 - accuracy: 0.8573 - val_loss: 1.2580 - val_accuracy: 0.6358
# Epoch 34/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2894 - accuracy: 0.8606 - val_loss: 1.2816 - val_accuracy: 0.6244
# Epoch 35/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2862 - accuracy: 0.8677 - val_loss: 1.2752 - val_accuracy: 0.6293
# Epoch 36/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2848 - accuracy: 0.8585 - val_loss: 1.2974 - val_accuracy: 0.6260
# Epoch 37/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2960 - accuracy: 0.8564 - val_loss: 1.3778 - val_accuracy: 0.6333
# Epoch 38/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2778 - accuracy: 0.8698 - val_loss: 1.3928 - val_accuracy: 0.6447
# Epoch 39/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2768 - accuracy: 0.8740 - val_loss: 1.3540 - val_accuracy: 0.6285
# Epoch 40/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2785 - accuracy: 0.8698 - val_loss: 1.2024 - val_accuracy: 0.6301
# Epoch 41/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2601 - accuracy: 0.8702 - val_loss: 1.4876 - val_accuracy: 0.6358
# Epoch 42/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2617 - accuracy: 0.8831 - val_loss: 1.4305 - val_accuracy: 0.6220
# Epoch 43/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2387 - accuracy: 0.8923 - val_loss: 1.6448 - val_accuracy: 0.6325
# Epoch 44/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2446 - accuracy: 0.8848 - val_loss: 1.5331 - val_accuracy: 0.6146
# Epoch 45/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2470 - accuracy: 0.8894 - val_loss: 1.5378 - val_accuracy: 0.6333
# Epoch 46/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2320 - accuracy: 0.8940 - val_loss: 1.6109 - val_accuracy: 0.6390
# Epoch 47/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2398 - accuracy: 0.8965 - val_loss: 1.4585 - val_accuracy: 0.6130
# Epoch 48/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2337 - accuracy: 0.8973 - val_loss: 1.6625 - val_accuracy: 0.6415
# Epoch 49/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2345 - accuracy: 0.8961 - val_loss: 1.6501 - val_accuracy: 0.6268
# Epoch 50/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2142 - accuracy: 0.9019 - val_loss: 1.5856 - val_accuracy: 0.6276
# Epoch 51/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2162 - accuracy: 0.9069 - val_loss: 1.8496 - val_accuracy: 0.6333
# Epoch 52/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2222 - accuracy: 0.9011 - val_loss: 1.8168 - val_accuracy: 0.6350
# Epoch 53/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2131 - accuracy: 0.9094 - val_loss: 1.6730 - val_accuracy: 0.6163
# Epoch 54/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2094 - accuracy: 0.9065 - val_loss: 2.0202 - val_accuracy: 0.6220
# Epoch 55/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2044 - accuracy: 0.9040 - val_loss: 1.6144 - val_accuracy: 0.6187
# Epoch 56/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.2050 - accuracy: 0.9136 - val_loss: 1.6067 - val_accuracy: 0.6114
# Epoch 57/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1958 - accuracy: 0.9132 - val_loss: 1.7435 - val_accuracy: 0.6309
# Epoch 58/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1982 - accuracy: 0.9111 - val_loss: 1.7518 - val_accuracy: 0.6244
# Epoch 59/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1859 - accuracy: 0.9169 - val_loss: 1.9685 - val_accuracy: 0.6195
# Epoch 60/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1851 - accuracy: 0.9290 - val_loss: 1.9457 - val_accuracy: 0.6228
# Epoch 61/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1948 - accuracy: 0.9186 - val_loss: 1.8630 - val_accuracy: 0.6285
# Epoch 62/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1860 - accuracy: 0.9140 - val_loss: 1.9064 - val_accuracy: 0.6122
# Epoch 63/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1771 - accuracy: 0.9224 - val_loss: 1.9287 - val_accuracy: 0.6114
# Epoch 64/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1934 - accuracy: 0.9211 - val_loss: 1.9204 - val_accuracy: 0.6350
# Epoch 65/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1573 - accuracy: 0.9412 - val_loss: 2.0104 - val_accuracy: 0.6211
# Epoch 66/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1590 - accuracy: 0.9303 - val_loss: 2.0766 - val_accuracy: 0.6260
# Epoch 67/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1820 - accuracy: 0.9245 - val_loss: 1.8956 - val_accuracy: 0.6228
# Epoch 68/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1677 - accuracy: 0.9328 - val_loss: 1.9308 - val_accuracy: 0.6228
# Epoch 69/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1815 - accuracy: 0.9286 - val_loss: 1.7670 - val_accuracy: 0.6341
# Epoch 70/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1787 - accuracy: 0.9249 - val_loss: 1.7531 - val_accuracy: 0.6073
# Epoch 71/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1631 - accuracy: 0.9320 - val_loss: 1.8499 - val_accuracy: 0.6098
# Epoch 72/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1645 - accuracy: 0.9278 - val_loss: 1.9666 - val_accuracy: 0.6138
# Epoch 73/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1556 - accuracy: 0.9316 - val_loss: 2.0575 - val_accuracy: 0.6252
# Epoch 74/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1557 - accuracy: 0.9403 - val_loss: 2.0378 - val_accuracy: 0.6244
# Epoch 75/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1482 - accuracy: 0.9311 - val_loss: 2.0815 - val_accuracy: 0.6106
# Epoch 76/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1643 - accuracy: 0.9336 - val_loss: 1.9750 - val_accuracy: 0.6260
# Epoch 77/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1406 - accuracy: 0.9441 - val_loss: 2.0780 - val_accuracy: 0.6220
# Epoch 78/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1527 - accuracy: 0.9353 - val_loss: 2.2570 - val_accuracy: 0.6211
# Epoch 79/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1538 - accuracy: 0.9416 - val_loss: 2.1863 - val_accuracy: 0.6146
# Epoch 80/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1536 - accuracy: 0.9374 - val_loss: 2.1010 - val_accuracy: 0.6228
# Epoch 81/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1464 - accuracy: 0.9378 - val_loss: 2.0620 - val_accuracy: 0.6374
# Epoch 82/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1489 - accuracy: 0.9353 - val_loss: 2.3779 - val_accuracy: 0.6252
# Epoch 83/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1526 - accuracy: 0.9428 - val_loss: 2.2355 - val_accuracy: 0.6309
# Epoch 84/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1343 - accuracy: 0.9457 - val_loss: 2.2368 - val_accuracy: 0.6276
# Epoch 85/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1498 - accuracy: 0.9395 - val_loss: 1.9511 - val_accuracy: 0.6317
# Epoch 86/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1233 - accuracy: 0.9495 - val_loss: 2.2462 - val_accuracy: 0.6163
# Epoch 87/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1469 - accuracy: 0.9349 - val_loss: 2.4893 - val_accuracy: 0.6163
# Epoch 88/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1310 - accuracy: 0.9487 - val_loss: 2.4317 - val_accuracy: 0.6122
# Epoch 89/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1291 - accuracy: 0.9499 - val_loss: 2.2849 - val_accuracy: 0.6171
# Epoch 90/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1268 - accuracy: 0.9512 - val_loss: 2.2569 - val_accuracy: 0.6309
# Epoch 91/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1303 - accuracy: 0.9466 - val_loss: 2.1561 - val_accuracy: 0.6260
# Epoch 92/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1214 - accuracy: 0.9512 - val_loss: 2.3702 - val_accuracy: 0.6130
# Epoch 93/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1438 - accuracy: 0.9391 - val_loss: 2.3225 - val_accuracy: 0.6130
# Epoch 94/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1287 - accuracy: 0.9441 - val_loss: 2.2662 - val_accuracy: 0.6260
# Epoch 95/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1135 - accuracy: 0.9558 - val_loss: 2.3527 - val_accuracy: 0.6228
# Epoch 96/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1051 - accuracy: 0.9591 - val_loss: 2.4603 - val_accuracy: 0.6317
# Epoch 97/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1403 - accuracy: 0.9478 - val_loss: 2.2643 - val_accuracy: 0.6236
# Epoch 98/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1189 - accuracy: 0.9491 - val_loss: 2.4255 - val_accuracy: 0.6057
# Epoch 99/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1129 - accuracy: 0.9583 - val_loss: 2.4705 - val_accuracy: 0.6236
# Epoch 100/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1170 - accuracy: 0.9499 - val_loss: 2.4643 - val_accuracy: 0.6317
# Epoch 101/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1159 - accuracy: 0.9537 - val_loss: 2.3880 - val_accuracy: 0.6276
# Epoch 102/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1259 - accuracy: 0.9474 - val_loss: 2.4482 - val_accuracy: 0.6211
# Epoch 103/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1201 - accuracy: 0.9562 - val_loss: 2.3568 - val_accuracy: 0.6228
# Epoch 104/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1159 - accuracy: 0.9549 - val_loss: 2.4210 - val_accuracy: 0.6260
# Epoch 105/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1146 - accuracy: 0.9533 - val_loss: 2.4827 - val_accuracy: 0.6236
# Epoch 106/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1138 - accuracy: 0.9533 - val_loss: 2.4637 - val_accuracy: 0.6228
# Epoch 107/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1082 - accuracy: 0.9578 - val_loss: 2.4916 - val_accuracy: 0.6285
# Epoch 108/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1127 - accuracy: 0.9570 - val_loss: 2.5411 - val_accuracy: 0.6260
# Epoch 109/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1135 - accuracy: 0.9549 - val_loss: 2.4953 - val_accuracy: 0.6285
# Epoch 110/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0979 - accuracy: 0.9633 - val_loss: 2.6852 - val_accuracy: 0.6236
# Epoch 111/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1116 - accuracy: 0.9583 - val_loss: 2.4664 - val_accuracy: 0.6276
# Epoch 112/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1064 - accuracy: 0.9595 - val_loss: 2.5545 - val_accuracy: 0.6333
# Epoch 113/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1169 - accuracy: 0.9562 - val_loss: 2.4275 - val_accuracy: 0.6236
# Epoch 114/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1022 - accuracy: 0.9595 - val_loss: 2.5242 - val_accuracy: 0.6398
# Epoch 115/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1051 - accuracy: 0.9620 - val_loss: 2.6071 - val_accuracy: 0.6260
# Epoch 116/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0971 - accuracy: 0.9624 - val_loss: 2.8574 - val_accuracy: 0.6276
# Epoch 117/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1018 - accuracy: 0.9574 - val_loss: 2.5682 - val_accuracy: 0.6154
# Epoch 118/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1142 - accuracy: 0.9545 - val_loss: 2.4865 - val_accuracy: 0.6293
# Epoch 119/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0931 - accuracy: 0.9624 - val_loss: 2.7428 - val_accuracy: 0.6260
# Epoch 120/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0993 - accuracy: 0.9645 - val_loss: 2.7259 - val_accuracy: 0.6138
# Epoch 121/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0938 - accuracy: 0.9633 - val_loss: 3.0020 - val_accuracy: 0.6276
# Epoch 122/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0927 - accuracy: 0.9629 - val_loss: 2.7238 - val_accuracy: 0.6358
# Epoch 123/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0928 - accuracy: 0.9591 - val_loss: 3.0251 - val_accuracy: 0.6415
# Epoch 124/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0783 - accuracy: 0.9670 - val_loss: 2.9861 - val_accuracy: 0.6268
# Epoch 125/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0991 - accuracy: 0.9583 - val_loss: 2.9158 - val_accuracy: 0.6293
# Epoch 126/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0969 - accuracy: 0.9587 - val_loss: 3.3847 - val_accuracy: 0.6203
# Epoch 127/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0948 - accuracy: 0.9637 - val_loss: 2.9085 - val_accuracy: 0.6211
# Epoch 128/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0994 - accuracy: 0.9633 - val_loss: 2.7871 - val_accuracy: 0.6285
# Epoch 129/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0963 - accuracy: 0.9629 - val_loss: 2.8988 - val_accuracy: 0.6309
# Epoch 130/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0906 - accuracy: 0.9649 - val_loss: 3.0414 - val_accuracy: 0.6236
# Epoch 131/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0944 - accuracy: 0.9649 - val_loss: 2.8537 - val_accuracy: 0.6285
# Epoch 132/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0937 - accuracy: 0.9599 - val_loss: 2.7491 - val_accuracy: 0.6285
# Epoch 133/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0961 - accuracy: 0.9641 - val_loss: 2.9086 - val_accuracy: 0.6350
# Epoch 134/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.1018 - accuracy: 0.9633 - val_loss: 2.7703 - val_accuracy: 0.6244
# Epoch 135/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0805 - accuracy: 0.9691 - val_loss: 2.9204 - val_accuracy: 0.6268
# Epoch 136/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0856 - accuracy: 0.9679 - val_loss: 2.8146 - val_accuracy: 0.6228
# Epoch 137/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0905 - accuracy: 0.9658 - val_loss: 2.6518 - val_accuracy: 0.6244
# Epoch 138/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0824 - accuracy: 0.9712 - val_loss: 2.9241 - val_accuracy: 0.6268
# Epoch 139/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0810 - accuracy: 0.9687 - val_loss: 2.9572 - val_accuracy: 0.6220
# Epoch 140/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0778 - accuracy: 0.9708 - val_loss: 3.1403 - val_accuracy: 0.6407
# Epoch 141/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0778 - accuracy: 0.9725 - val_loss: 3.0535 - val_accuracy: 0.6228
# Epoch 142/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1012 - accuracy: 0.9641 - val_loss: 2.6768 - val_accuracy: 0.6309
# Epoch 143/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0788 - accuracy: 0.9704 - val_loss: 2.9571 - val_accuracy: 0.6276
# Epoch 144/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0803 - accuracy: 0.9695 - val_loss: 2.8330 - val_accuracy: 0.6333
# Epoch 145/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0815 - accuracy: 0.9658 - val_loss: 3.0997 - val_accuracy: 0.6122
# Epoch 146/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0775 - accuracy: 0.9699 - val_loss: 3.1425 - val_accuracy: 0.6276
# Epoch 147/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0792 - accuracy: 0.9683 - val_loss: 3.2835 - val_accuracy: 0.6341
# Epoch 148/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0816 - accuracy: 0.9683 - val_loss: 2.9753 - val_accuracy: 0.6341
# Epoch 149/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0781 - accuracy: 0.9691 - val_loss: 2.8732 - val_accuracy: 0.6276
# Epoch 150/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0916 - accuracy: 0.9683 - val_loss: 3.1153 - val_accuracy: 0.6398
# Epoch 151/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0731 - accuracy: 0.9758 - val_loss: 3.2207 - val_accuracy: 0.6398
# Epoch 152/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0848 - accuracy: 0.9670 - val_loss: 2.8609 - val_accuracy: 0.6276
# Epoch 153/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0828 - accuracy: 0.9679 - val_loss: 2.7916 - val_accuracy: 0.6220
# Epoch 154/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.1024 - accuracy: 0.9587 - val_loss: 2.6292 - val_accuracy: 0.6293
# Epoch 155/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0736 - accuracy: 0.9729 - val_loss: 3.1031 - val_accuracy: 0.6187
# Epoch 156/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0813 - accuracy: 0.9666 - val_loss: 3.1466 - val_accuracy: 0.6220
# Epoch 157/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0732 - accuracy: 0.9720 - val_loss: 3.0983 - val_accuracy: 0.6244
# Epoch 158/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0845 - accuracy: 0.9649 - val_loss: 3.0320 - val_accuracy: 0.6228
# Epoch 159/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0756 - accuracy: 0.9716 - val_loss: 2.9700 - val_accuracy: 0.6309
# Epoch 160/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0820 - accuracy: 0.9658 - val_loss: 3.0905 - val_accuracy: 0.6366
# Epoch 161/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0878 - accuracy: 0.9679 - val_loss: 2.9595 - val_accuracy: 0.6016
# Epoch 162/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0895 - accuracy: 0.9629 - val_loss: 2.9993 - val_accuracy: 0.6228
# Epoch 163/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0741 - accuracy: 0.9712 - val_loss: 3.0921 - val_accuracy: 0.6220
# Epoch 164/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0962 - accuracy: 0.9608 - val_loss: 2.9324 - val_accuracy: 0.6341
# Epoch 165/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0761 - accuracy: 0.9699 - val_loss: 3.2089 - val_accuracy: 0.6301
# Epoch 166/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0761 - accuracy: 0.9712 - val_loss: 3.1692 - val_accuracy: 0.6154
# Epoch 167/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0608 - accuracy: 0.9795 - val_loss: 3.3935 - val_accuracy: 0.6211
# Epoch 168/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0749 - accuracy: 0.9737 - val_loss: 3.5106 - val_accuracy: 0.6341
# Epoch 169/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0627 - accuracy: 0.9779 - val_loss: 3.2043 - val_accuracy: 0.6260
# Epoch 170/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0773 - accuracy: 0.9733 - val_loss: 3.1419 - val_accuracy: 0.6276
# Epoch 171/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0926 - accuracy: 0.9699 - val_loss: 2.9447 - val_accuracy: 0.6301
# Epoch 172/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0575 - accuracy: 0.9804 - val_loss: 3.4277 - val_accuracy: 0.6390
# Epoch 173/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0905 - accuracy: 0.9699 - val_loss: 2.9609 - val_accuracy: 0.6317
# Epoch 174/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0724 - accuracy: 0.9708 - val_loss: 3.0583 - val_accuracy: 0.6171
# Epoch 175/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0739 - accuracy: 0.9712 - val_loss: 2.8589 - val_accuracy: 0.6171
# Epoch 176/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0499 - accuracy: 0.9821 - val_loss: 3.5527 - val_accuracy: 0.6293
# Epoch 177/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0695 - accuracy: 0.9766 - val_loss: 3.3765 - val_accuracy: 0.6195
# Epoch 178/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0740 - accuracy: 0.9712 - val_loss: 3.7054 - val_accuracy: 0.6211
# Epoch 179/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0864 - accuracy: 0.9695 - val_loss: 3.1918 - val_accuracy: 0.6236
# Epoch 180/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0591 - accuracy: 0.9741 - val_loss: 3.2000 - val_accuracy: 0.6285
# Epoch 181/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0747 - accuracy: 0.9733 - val_loss: 3.3070 - val_accuracy: 0.6309
# Epoch 182/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0723 - accuracy: 0.9720 - val_loss: 3.3187 - val_accuracy: 0.6276
# Epoch 183/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0653 - accuracy: 0.9779 - val_loss: 3.4586 - val_accuracy: 0.6203
# Epoch 184/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0720 - accuracy: 0.9725 - val_loss: 3.5386 - val_accuracy: 0.6236
# Epoch 185/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0608 - accuracy: 0.9787 - val_loss: 3.5224 - val_accuracy: 0.6244
# Epoch 186/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0789 - accuracy: 0.9712 - val_loss: 3.0837 - val_accuracy: 0.6358
# Epoch 187/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0620 - accuracy: 0.9762 - val_loss: 3.5272 - val_accuracy: 0.6276
# Epoch 188/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0716 - accuracy: 0.9712 - val_loss: 3.3590 - val_accuracy: 0.6325
# Epoch 189/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0704 - accuracy: 0.9708 - val_loss: 3.2282 - val_accuracy: 0.6276
# Epoch 190/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0694 - accuracy: 0.9750 - val_loss: 3.3120 - val_accuracy: 0.6154
# Epoch 191/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0708 - accuracy: 0.9729 - val_loss: 3.1462 - val_accuracy: 0.6171
# Epoch 192/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0640 - accuracy: 0.9750 - val_loss: 3.3578 - val_accuracy: 0.6195
# Epoch 193/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0666 - accuracy: 0.9791 - val_loss: 3.5973 - val_accuracy: 0.6276
# Epoch 194/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0655 - accuracy: 0.9804 - val_loss: 3.5449 - val_accuracy: 0.6252
# Epoch 195/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0698 - accuracy: 0.9783 - val_loss: 3.2389 - val_accuracy: 0.6350
# Epoch 196/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0631 - accuracy: 0.9745 - val_loss: 3.4555 - val_accuracy: 0.6236
# Epoch 197/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0650 - accuracy: 0.9737 - val_loss: 3.4026 - val_accuracy: 0.6268
# Epoch 198/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0596 - accuracy: 0.9783 - val_loss: 3.4108 - val_accuracy: 0.6252
# Epoch 199/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0644 - accuracy: 0.9770 - val_loss: 3.5427 - val_accuracy: 0.6228
# Epoch 200/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0750 - accuracy: 0.9699 - val_loss: 3.4697 - val_accuracy: 0.6260
# Epoch 201/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0793 - accuracy: 0.9758 - val_loss: 3.2715 - val_accuracy: 0.6203
# Epoch 202/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0537 - accuracy: 0.9812 - val_loss: 3.8497 - val_accuracy: 0.6220
# Epoch 203/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0620 - accuracy: 0.9787 - val_loss: 3.6896 - val_accuracy: 0.6220
# Epoch 204/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0577 - accuracy: 0.9758 - val_loss: 4.0407 - val_accuracy: 0.6179
# Epoch 205/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0847 - accuracy: 0.9720 - val_loss: 3.6992 - val_accuracy: 0.6268
# Epoch 206/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0540 - accuracy: 0.9808 - val_loss: 3.5927 - val_accuracy: 0.6146
# Epoch 207/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0755 - accuracy: 0.9745 - val_loss: 3.3821 - val_accuracy: 0.6195
# Epoch 208/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0555 - accuracy: 0.9816 - val_loss: 3.8593 - val_accuracy: 0.6333
# Epoch 209/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0463 - accuracy: 0.9829 - val_loss: 4.0717 - val_accuracy: 0.6285
# Epoch 210/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0791 - accuracy: 0.9750 - val_loss: 3.3885 - val_accuracy: 0.6309
# Epoch 211/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0714 - accuracy: 0.9745 - val_loss: 3.2781 - val_accuracy: 0.6276
# Epoch 212/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0535 - accuracy: 0.9808 - val_loss: 3.6227 - val_accuracy: 0.6252
# Epoch 213/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0646 - accuracy: 0.9770 - val_loss: 3.4978 - val_accuracy: 0.6187
# Epoch 214/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0680 - accuracy: 0.9745 - val_loss: 3.6614 - val_accuracy: 0.6203
# Epoch 215/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0567 - accuracy: 0.9779 - val_loss: 3.7939 - val_accuracy: 0.6260
# Epoch 216/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0597 - accuracy: 0.9795 - val_loss: 3.7871 - val_accuracy: 0.6276
# Epoch 217/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0607 - accuracy: 0.9770 - val_loss: 3.7851 - val_accuracy: 0.6268
# Epoch 218/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0693 - accuracy: 0.9758 - val_loss: 3.5250 - val_accuracy: 0.6276
# Epoch 219/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0553 - accuracy: 0.9804 - val_loss: 3.9925 - val_accuracy: 0.6236
# Epoch 220/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0577 - accuracy: 0.9808 - val_loss: 3.7306 - val_accuracy: 0.6220
# Epoch 221/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0600 - accuracy: 0.9779 - val_loss: 3.4974 - val_accuracy: 0.6301
# Epoch 222/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0440 - accuracy: 0.9846 - val_loss: 3.9174 - val_accuracy: 0.6333
# Epoch 223/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0528 - accuracy: 0.9821 - val_loss: 3.5390 - val_accuracy: 0.6187
# Epoch 224/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0591 - accuracy: 0.9795 - val_loss: 4.1546 - val_accuracy: 0.6236
# Epoch 225/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0632 - accuracy: 0.9770 - val_loss: 3.7800 - val_accuracy: 0.6244
# Epoch 226/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0490 - accuracy: 0.9833 - val_loss: 3.8830 - val_accuracy: 0.6285
# Epoch 227/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0576 - accuracy: 0.9791 - val_loss: 3.4830 - val_accuracy: 0.6244
# Epoch 228/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0594 - accuracy: 0.9758 - val_loss: 3.5276 - val_accuracy: 0.6268
# Epoch 229/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0412 - accuracy: 0.9858 - val_loss: 4.0888 - val_accuracy: 0.6228
# Epoch 230/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0523 - accuracy: 0.9804 - val_loss: 3.7545 - val_accuracy: 0.6268
# Epoch 231/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0504 - accuracy: 0.9841 - val_loss: 4.2148 - val_accuracy: 0.6211
# Epoch 232/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0611 - accuracy: 0.9775 - val_loss: 3.7621 - val_accuracy: 0.6220
# Epoch 233/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0402 - accuracy: 0.9825 - val_loss: 4.7285 - val_accuracy: 0.6154
# Epoch 234/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0642 - accuracy: 0.9808 - val_loss: 4.0437 - val_accuracy: 0.6220
# Epoch 235/250
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0591 - accuracy: 0.9783 - val_loss: 4.1153 - val_accuracy: 0.6260
# Epoch 236/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0483 - accuracy: 0.9829 - val_loss: 3.8746 - val_accuracy: 0.6228
# Epoch 237/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0659 - accuracy: 0.9779 - val_loss: 3.7771 - val_accuracy: 0.6301
# Epoch 238/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0495 - accuracy: 0.9837 - val_loss: 3.8261 - val_accuracy: 0.6285
# Epoch 239/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0523 - accuracy: 0.9812 - val_loss: 3.9956 - val_accuracy: 0.6203
# Epoch 240/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0485 - accuracy: 0.9791 - val_loss: 4.1408 - val_accuracy: 0.6301
# Epoch 241/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0661 - accuracy: 0.9737 - val_loss: 3.6891 - val_accuracy: 0.6268
# Epoch 242/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0516 - accuracy: 0.9829 - val_loss: 4.5900 - val_accuracy: 0.6341
# Epoch 243/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0429 - accuracy: 0.9846 - val_loss: 4.1659 - val_accuracy: 0.6382
# Epoch 244/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0611 - accuracy: 0.9737 - val_loss: 3.7718 - val_accuracy: 0.6374
# Epoch 245/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0488 - accuracy: 0.9850 - val_loss: 4.2291 - val_accuracy: 0.6285
# Epoch 246/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0405 - accuracy: 0.9850 - val_loss: 4.6699 - val_accuracy: 0.6285
# Epoch 247/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0749 - accuracy: 0.9725 - val_loss: 3.8539 - val_accuracy: 0.6146
# Epoch 248/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0609 - accuracy: 0.9791 - val_loss: 3.9745 - val_accuracy: 0.6309
# Epoch 249/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0461 - accuracy: 0.9833 - val_loss: 4.1028 - val_accuracy: 0.6293
# Epoch 250/250
# 480/480 [==============================] - 2s 3ms/step - loss: 0.0470 - accuracy: 0.9816 - val_loss: 4.3253 - val_accuracy: 0.6252

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
probs = model.predict(X_test_revised)[:,0]
preds_r = np.round(probs,0)
print(accuracy_score(preds_r, y_test))
# Out:
# 0.6252032520325204

# %%
# nn_df = X_test.copy()
# nn_df['HOME_WIN'] = y_test
# nn_df['PREDS'] = preds_r
# nn_df['ERROR'] = abs(nn_df.HOME_WIN - nn_df.PREDS)

# error_df = nn_df.groupby(by=['ERROR']).sum()

# error_dict = dict()
# for col in error_df.columns:
#   away_col = 'AWAY_' + col
#   val = error_df[col].loc[1] + error_df[away_col].loc[1]
#   error_dict[col] = [val]

# error_total_df = pd.DataFrame.from_dict(error_dict).transpose()
# error_total_df = error_total_df.rename(columns={0:'ERROR_TOTAL'})
# error_total_df.sort_values(by='ERROR_TOTAL', ascending=False)

# %%
# error_total_df

# %%
#model.save(root_path + '/data/neural_network_checkpoint_2')
# Out:
# INFO:tensorflow:Assets written to: drive/MyDrive/NBA-predictions/data/neural_network_checkpoint_2/assets

# %%
# model_best = models.load_model(root_path + '/data/neural_network_checkpoint') # 16 columns

# %%
# probs = model_best.predict(X_test_revised)[:,0]
# preds_r = np.round(probs,0)
# print(accuracy_score(preds_r, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-e7b248c16e40> in <module>()
# ----> 1 probs = model_best.predict(X_test_revised)[:,0]
#       2 preds_r = np.round(probs,0)
#       3 print(accuracy_score(preds_r, y_test))
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1749           for step in data_handler.steps():
#    1750             callbacks.on_predict_batch_begin(step)
# -> 1751             tmp_batch_outputs = self.predict_function(iterator)
#    1752             if data_handler.should_sync:
#    1753               context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     758     self._concrete_stateful_fn = (
#     759         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 760             *args, **kwds))
#     761
#     762     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3064       args, kwargs = None, None
#    3065     with self._lock:
# -> 3066       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3067     return graph_function
#    3068
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
# -> 3463           graph_function = self._create_graph_function(args, kwargs)
#    3464           self._function_cache.primary[cache_key] = graph_function
#    3465
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3306             arg_names=arg_names,
#    3307             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3308             capture_by_value=self._capture_by_value),
#    3309         self._function_attributes,
#    3310         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     666         # the function a weak reference to itself to avoid a reference cycle.
#     667         with OptionalXlaContext(compile_with_xla):
# --> 668           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     669         return out
#     670
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     992           except Exception as e:  # pylint:disable=broad-except
#     993             if hasattr(e, "ag_error_metadata"):
# --> 994               raise e.ag_error_metadata.to_exception(e)
#     995             else:
#     996               raise
#
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1586 predict_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1576 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:1286 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:2849 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:3632 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1569 run_step  **
#         outputs = model.predict_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1537 predict_step
#         return self(x, training=False)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:1020 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:254 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential is incompatible with the layer: expected axis -1 of input shape to have value 16 but received input with shape (None, 76)

# %%
# nn_df = X_test.copy()
# nn_df['HOME_WIN'] = y_test
# nn_df['PREDS'] = preds_r
# nn_df['ERROR'] = abs(nn_df.HOME_WIN - nn_df.PREDS)

# error_df = nn_df.groupby(by=['ERROR']).sum()

# error_dict = dict()
# for col in error_df.columns[:30]:
#   away_col = 'AWAY_' + col
#   val = error_df[col].loc[1] + error_df[away_col].loc[1]
#   error_dict[col] = [val]

# error_total_df = pd.DataFrame.from_dict(error_dict).transpose()
# error_total_df = error_total_df.rename(columns={0:'ERROR_TOTAL'})
# error_total_df = error_total_df.sort_values(by='ERROR_TOTAL', ascending=False)
error_total_df
# Out:
#      ERROR_TOTAL
# CHI           36
# DET           34
# MIN           34
# ATL           33
# MIL           33
# BKN           33
# HOU           33
# WAS           33
# MIA           32
# BOS           32
# DAL           32
# IND           31
# UTA           30
# POR           30
# PHX           30
# OKC           29
# NOP           29
# NYK           29
# CLE           29
# DEN           28
# CHA           27
# ORL           27
# SAC           24
# PHI           23
# MEM           23
# TOR           23
# LAC           23
# GSW           21
# LAL           19
# SAS           16

# %%
model_overfit = models.load_model(root_path + '/data/neural_network_checkpoint_2') # 76 columns

# %%
probs = model_overfit.predict(X_test_revised)[:,0]
preds_r = np.round(probs,0)
print(accuracy_score(preds_r, y_test))
# Out:
# 0.6560975609756098

# %%
nn_df = X_test.copy()
nn_df['HOME_WIN'] = y_test
nn_df['PREDS'] = preds_r
nn_df['ERROR'] = abs(nn_df.HOME_WIN - nn_df.PREDS)

error_df = nn_df.groupby(by=['ERROR']).sum()

error_dict = dict()
for col in error_df.columns[:30]:
  away_col = 'AWAY_' + col
  val = error_df[col].loc[1] + error_df[away_col].loc[1]
  error_dict[col] = [val]

error_total_df = pd.DataFrame.from_dict(error_dict).transpose()
error_total_df = error_total_df.rename(columns={0:'ERROR_TOTAL'})
error_total_df = error_total_df.sort_values(by='ERROR_TOTAL', ascending=False)
error_total_df
# Out:
#      ERROR_TOTAL
# BKN           40
# DEN           39
# MIA           37
# ATL           36
# HOU           35
# NOP           35
# UTA           34
# PHX           34
# POR           32
# MIL           32
# MIN           31
# BOS           31
# CHA           31
# DET           31
# MEM           31
# CHI           30
# WAS           30
# ORL           29
# CLE           27
# SAC           27
# DAL           27
# OKC           26
# IND           26
# NYK           22
# TOR           21
# LAC           20
# PHI           14
# GSW           14
# SAS           13
# LAL           11
