# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure

# %%
from google.colab import drive
drive.mount('/content/drive')

root_path = 'drive/MyDrive/NBA-predictions'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# our data consists of all regular season games from 2013 to the end of the 2015 season
all_games = pd.read_csv(root_path +'/data/nba_games_2013_2015.csv', sep=';')
all_games = all_games.sort_values(by=['GAME_DATE'])

# %%
all_games.head()
# Out:
#       SEASON_ID     TEAM_ID TEAM_ABBREVIATION  ... TOV  PF PLUS_MINUS
# 7379      22013  1610612754               IND  ...  20  13       10.0
# 7374      22013  1610612746               LAC  ...  16  21      -13.0
# 7375      22013  1610612753               ORL  ...  17  26      -10.0
# 7378      22013  1610612741               CHI  ...  18  27      -12.0
# 7377      22013  1610612747               LAL  ...  19  23       13.0
#
# [5 rows x 28 columns]

# %%
df = all_games.copy()

# %%
# Miami (MIA) and Oklahoma (OKC) were the 2 finalists in 2012 - let's look at some of their season average stats.
df_2012 = pd.read_csv(root_path +'/data/2012_team_averages.csv')

# %%
df_2012.head()
# Out:
#                     TEAM  GP   W   L   WIN%  ...  BLK  BLKA    PF   PFD  +/-
# 0             Miami Heat  82  66  16  0.805  ...  5.4   3.2  18.7  20.4  7.9
# 1  Oklahoma City Thunder  82  60  22  0.732  ...  7.6   3.9  20.2  20.7  9.2
# 2      San Antonio Spurs  82  58  24  0.707  ...  5.4   4.9  17.4  19.1  6.4
# 3         Denver Nuggets  82  57  25  0.695  ...  6.5   6.8  20.5  21.6  5.1
# 4   Los Angeles Clippers  82  56  26  0.683  ...  5.6   4.1  20.9  20.9  6.5
#
# [5 rows x 27 columns]

# %%
df_2012.describe()
# Out:
#               GP          W          L  ...         PF        PFD        +/-
# count  30.000000  30.000000  30.000000  ...  30.000000  30.000000  30.000000
# mean   81.933333  40.966667  40.966667  ...  19.843333  19.840000   0.000000
# std     0.253708  12.710255  12.734648  ...   1.238376   1.512158   4.608687
# min    81.000000  20.000000  16.000000  ...  17.400000  16.200000  -9.200000
# 25%    82.000000  29.500000  32.250000  ...  18.775000  19.100000  -3.275000
# 50%    82.000000  42.000000  39.500000  ...  20.150000  19.800000  -0.150000
# 75%    82.000000  49.000000  52.500000  ...  20.675000  20.625000   3.875000
# max    82.000000  66.000000  62.000000  ...  22.400000  23.100000   9.200000
#
# [8 rows x 26 columns]

# %%
df_2012['+/-'][:8].sort_values
# Out:
# <bound method Series.sort_values of 0    7.9
# 1    9.2
# 2    6.4
# 3    5.1
# 4    6.5
# 5    4.1
# 6    4.2
# 7    1.8
# Name: +/-, dtype: float64>

# %%
def plot_hist_best_n(df=df_2012, x='+/-', bins=8, best_n=3, figsize=(12, 9)):
  import matplotlib.pyplot as plt
  import seaborn as sns
  from matplotlib.pyplot import figure

  from matplotlib import rcParams

  # figure size in inches
  rcParams['figure.figsize'] = figsize
  '''
  Plots a histogram for the given column, plotting lines at specified locations indicating the top entries in the (presumably) sorted dataframe.

  `df` = DataFrame
  `column_iloc` = (int)  : the index for the column to be returned
  `best_n` = (int) : the # of entry values to be returned
      **best_n note: works with 8 entries or less (due to colors)

  `bins` = (int) : number of bins for histogram,

  Example:
    plot_hist_best_n(df=df_2012, x='+/-', bins=8, column_iloc=-1, best_n=8)

    line = plt.axvline(df_2012.iloc[best_n][column_iloc], 0, 6, c='orangered')

  '''
  
  # color dictionary for line colors
  # uses a heat scale (gold for #1)
  color_dict = {
      0 : 'gold',
      1 : 'y',
      2 : 'grey',
      3 : 'silver',
      4: 'sienna',
      5: 'saddlebrown',
      6: 'palevioletred',
      7: 'lightpink'
  }

  # copy df
  temp_df = df.copy()

  #a = sns.displot(temp_df, x=x, bins=bins)
  #a.figure.figsize = figsize
  plt.hist(temp_df[x], bins=bins)
  plt.grid(color='w', axis='x', linestyle='--')
  plt.xlabel(x, fontsize = 16)
  plt.ylabel("Count", fontsize=16)

  for i in range(best_n):

    line = plt.axvline(temp_df.iloc[i][x], 0, 30, c=color_dict[i], linewidth=4)
    line_title = str(f'{i+1}: '+ temp_df.iloc[i].TEAM) # set teamname
    line.set_label(line_title)

    print(line_title + ': ' + str(round(temp_df.iloc[i][x], 2)))
    #plt.annotate(str(i+1), xy=(temp_df.iloc[i][x], 0))
    #print(i)

  line = plt.axvline(temp_df[x].mean(), 0, 30, c='black', linewidth=2)
  line_title = 'Mean' # set label
  plt.annotate(line_title, xy=(temp_df[x].mean(), 0))
  line.set_label(line_title)
  plt.legend()

  print(line_title + ': ' + str(round(temp_df[x].mean(), 2)))
  
  return

# %%
# Histogram looking at the PLUS_MINUS of the top 8 teams
plot_scatter_best_n(
    df=df_2012, 
    x='+/-', 
    bins=8,  
    best_n=8, 
    figsize=(12, 7)
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-98130148d961> in <module>()
#       5     bins=8,
#       6     best_n=8,
# ----> 7     figsize=(12, 7)
#       8     )
#
# <ipython-input-48-06195756dc5e> in plot_scatter_best_n(df, x, bins, best_n, figsize)
#      43   #a = sns.displot(temp_df, x=x, bins=bins)
#      44   #a.figure.figsize = figsize
# ---> 45   plt.scatter(x=temp_df[x][:best_n], y=temp_df[x][:best_n].sort_values, bins=bins)
#      46   plt.grid(color='w', axis='xy', linestyle='--')
#      47   plt.xlabel(x, fontsize = 16)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4389         y = np.ma.ravel(y)
#    4390         if x.size != y.size:
# -> 4391             raise ValueError("x and y must be the same size")
#    4392
#    4393         if s is None:
#
# ValueError: x and y must be the same size

# %%
plot_hist_best_n(
    df=df_2012, 
    x='FG%', 
    bins='auto', 
    best_n=8, 
    figsize=(12, 7) 
    )
# Out:
# 1: Miami Heat: 49.6
# 2: Oklahoma City Thunder: 48.1
# 3: San Antonio Spurs: 48.1
# 4: Denver Nuggets: 47.8
# 5: Los Angeles Clippers: 47.8
# 6: Memphis Grizzlies: 44.4
# 7: New York Knicks: 44.8
# 8: Brooklyn Nets: 45.0
# Mean: 45.31

# %%
plot_hist_best_n(
    df=df_2012, 
    x='3P%', 
    bins='auto', 
    best_n=8, 
    figsize=(12, 7)
    )
# Out:
# 1: Miami Heat: 39.6
# 2: Oklahoma City Thunder: 37.7
# 3: San Antonio Spurs: 37.6
# 4: Denver Nuggets: 34.3
# 5: Los Angeles Clippers: 35.8
# 6: Memphis Grizzlies: 34.5
# 7: New York Knicks: 37.6
# 8: Brooklyn Nets: 35.7
# Mean: 35.76

# %%
plot_hist_best_n(
    df=df_2012, 
    x='FT%', 
    bins=10, 
    best_n=8, 
    figsize=(12, 7)
    )
# Out:
# 1: Miami Heat: 75.4
# 2: Oklahoma City Thunder: 82.8
# 3: San Antonio Spurs: 79.1
# 4: Denver Nuggets: 70.1
# 5: Los Angeles Clippers: 71.1
# 6: Memphis Grizzlies: 77.3
# 7: New York Knicks: 75.9
# 8: Brooklyn Nets: 73.1
# Mean: 75.35

# %%
plot_hist_best_n(
    df=df_2012, 
    x='REB', 
    bins='auto', 
    best_n=8, 
    figsize=(12, 7)
    )
# Out:
# 1: Miami Heat: 38.6
# 2: Oklahoma City Thunder: 43.6
# 3: San Antonio Spurs: 41.3
# 4: Denver Nuggets: 45.0
# 5: Los Angeles Clippers: 41.6
# 6: Memphis Grizzlies: 42.7
# 7: New York Knicks: 40.6
# 8: Brooklyn Nets: 42.8
# Mean: 42.13

# %%
plot_hist_best_n(
    df=df_2012, 
    x='STL', 
    bins='auto', 
    best_n=8, 
    figsize=(12, 7)
    )
# Out:
# 1: Miami Heat: 8.7
# 2: Oklahoma City Thunder: 8.3
# 3: San Antonio Spurs: 8.5
# 4: Denver Nuggets: 9.3
# 5: Los Angeles Clippers: 9.6
# 6: Memphis Grizzlies: 8.6
# 7: New York Knicks: 8.2
# 8: Brooklyn Nets: 7.3
# Mean: 7.81

# %%
def plot_histograms_of_interest(df=df_2012):
  '''
  Contains all of the histograms of interest, to save time.
  '''
  import matplotlib.pyplot as plt
  import seaborn as sns
  from matplotlib.pyplot import figure

  from matplotlib import rcParams

  plot_hist_best_n(
      df=df, 
      x='+/-', 
      bins='auto',
      best_n=8, 
      figsize=(12, 7)
      )
  plt.show()

  plot_hist_best_n(
      df=df,
      x='FG%', 
      bins='auto', 
      best_n=8, 
      figsize=(12, 7)
      )
  plt.show()
  
  plot_hist_best_n(
      df=df, 
      x='3P%', 
      bins='auto', 
      best_n=8, 
      figsize=(12, 7)
      )
  plt.show()
  
  plot_hist_best_n(
      df=df, 
      x='FT%', 
      bins='auto', 
      best_n=8, 
      figsize=(12, 7)
      )
  plt.show()
  
  plot_hist_best_n(
      df=df, 
      x='REB', 
      bins='auto', 
      best_n=8, 
      figsize=(12, 7)
      )
  plt.show()
  
  plot_hist_best_n(
      df=df, 
      x='STL', 
      bins='auto', 
      best_n=8, 
      figsize=(12, 7)
      )
  plt.show()

  plot_hist_best_n(
      df=df, 
      x='TOV', 
      bins='auto', 
      best_n=8, 
      figsize=(12, 7)
      )
  plt.show()

  return

# %%
# Let's normalize the data from above to see if there's any visual improvement
cols_to_normalize = ['+/-',
                     'FG%',
                     '3P%',
                     'FT%',
                     'REB',
                     'STL',
                     'TOV']

normalized_df = pd.DataFrame()
normalized_df['TEAM'] = df_2012['TEAM']

for col in cols_to_normalize:
  #print(col)
  temp = df_2012[col].values
  normalized_df[col] = (temp-temp.min())/(temp.max()-temp.min())

normalized_df.head()
# Out:
#                     TEAM       +/-       FG%  ...       REB       STL       TOV
# 0             Miami Heat  0.929348  1.000000  ...  0.000000  0.727273  0.431818
# 1  Oklahoma City Thunder  1.000000  0.788732  ...  0.684932  0.606061  0.750000
# 2      San Antonio Spurs  0.847826  0.788732  ...  0.369863  0.666667  0.613636
# 3         Denver Nuggets  0.777174  0.746479  ...  0.876712  0.909091  0.750000
# 4   Los Angeles Clippers  0.853261  0.746479  ...  0.410959  1.000000  0.590909
#
# [5 rows x 8 columns]

# %%
plot_histograms_of_interest(df=normalized_df)
# Out:
# 1: Miami Heat: 0.93
# 2: Oklahoma City Thunder: 1.0
# 3: San Antonio Spurs: 0.85
# 4: Denver Nuggets: 0.78
# 5: Los Angeles Clippers: 0.85
# 6: Memphis Grizzlies: 0.72
# 7: New York Knicks: 0.73
# 8: Brooklyn Nets: 0.6
# Mean: 0.5
# 1: Miami Heat: 1.0
# 2: Oklahoma City Thunder: 0.79
# 3: San Antonio Spurs: 0.79
# 4: Denver Nuggets: 0.75
# 5: Los Angeles Clippers: 0.75
# 6: Memphis Grizzlies: 0.27
# 7: New York Knicks: 0.32
# 8: Brooklyn Nets: 0.35
# Mean: 0.4
# 1: Miami Heat: 0.93
# 2: Oklahoma City Thunder: 0.73
# 3: San Antonio Spurs: 0.72
# 4: Denver Nuggets: 0.39
# 5: Los Angeles Clippers: 0.54
# 6: Memphis Grizzlies: 0.41
# 7: New York Knicks: 0.72
# 8: Brooklyn Nets: 0.53
# Mean: 0.54
# 1: Miami Heat: 0.46
# 2: Oklahoma City Thunder: 1.0
# 3: San Antonio Spurs: 0.73
# 4: Denver Nuggets: 0.07
# 5: Los Angeles Clippers: 0.14
# 6: Memphis Grizzlies: 0.6
# 7: New York Knicks: 0.49
# 8: Brooklyn Nets: 0.29
# Mean: 0.45
# 1: Miami Heat: 0.0
# 2: Oklahoma City Thunder: 0.68
# 3: San Antonio Spurs: 0.37
# 4: Denver Nuggets: 0.88
# 5: Los Angeles Clippers: 0.41
# 6: Memphis Grizzlies: 0.56
# 7: New York Knicks: 0.27
# 8: Brooklyn Nets: 0.58
# Mean: 0.48
# 1: Miami Heat: 0.73
# 2: Oklahoma City Thunder: 0.61
# 3: San Antonio Spurs: 0.67
# 4: Denver Nuggets: 0.91
# 5: Los Angeles Clippers: 1.0
# 6: Memphis Grizzlies: 0.7
# 7: New York Knicks: 0.58
# 8: Brooklyn Nets: 0.3
# Mean: 0.46
# 1: Miami Heat: 0.43
# 2: Oklahoma City Thunder: 0.75
# 3: San Antonio Spurs: 0.61
# 4: Denver Nuggets: 0.75
# 5: Los Angeles Clippers: 0.59
# 6: Memphis Grizzlies: 0.45
# 7: New York Knicks: 0.0
# 8: Brooklyn Nets: 0.61
# Mean: 0.58

# %%
# Let's look at the top 100 players (with respect to points) for the 2012 season, and see how many of them are on these top 8 teams.
top_players = pd.read_csv(root_path +'/data/top_100_players_2012.csv')
top_players.head(25)
# Out:
#                PLAYER TEAM  AGE  GP   W   L  ...  BLK   PF    FP  DD2  TD3  +/-
# 0     Carmelo Anthony  NYK   29  67  47  20  ...  0.5  3.1  41.9   10    0  4.6
# 1        Kevin Durant  OKC   24  81  60  21  ...  1.3  1.8  49.3   19    3  8.9
# 2         Kobe Bryant  LAL   34  78  42  36  ...  0.3  2.2  44.4   16    2  1.8
# 3        LeBron James  MIA   28  76  61  15  ...  0.9  1.4  52.1   36    4  9.5
# 4        James Harden  HOU   23  78  43  35  ...  0.5  2.3  43.7    9    1  2.5
# 5   Russell Westbrook  OKC   24  82  60  22  ...  0.3  2.3  43.4   23    1  7.7
# 6       Stephen Curry  GSW   25  78  45  33  ...  0.2  2.5  40.3   15    0  1.7
# 7        Kyrie Irving  CLE   21  59  19  40  ...  0.4  2.5  38.1    4    0 -3.0
# 8         Dwyane Wade  MIA   31  69  55  14  ...  0.8  2.0  40.0    4    0  8.3
# 9   LaMarcus Aldridge  POR   27  74  32  42  ...  1.2  2.5  40.1   38    0 -0.3
# 10        Tony Parker  SAS   31  66  47  19  ...  0.1  1.4  35.4   17    1  6.8
# 11        Brook Lopez  BKN   25  74  46  28  ...  2.1  2.1  35.0   12    0  3.9
# 12        Monta Ellis  MIL   27  82  38  44  ...  0.4  2.0  37.3    9    0 -0.5
# 13     Damian Lillard  POR   22  82  33  49  ...  0.2  2.1  33.0    7    0 -0.8
# 14     Deron Williams  BKN   29  78  46  32  ...  0.4  2.5  35.4   21    0  2.2
# 15        Paul Pierce  BOS   35  77  41  36  ...  0.4  2.7  35.0   12    3  1.6
# 16          John Wall  WAS   22  49  24  25  ...  0.8  2.4  37.7   14    0  0.9
# 17          David Lee  GSW   30  79  46  33  ...  0.3  3.1  38.0   56    1  2.2
# 18         Kevin Love  MIN   24  18   9   9  ...  0.5  1.9  40.1   14    0  0.1
# 19           Rudy Gay  TOR   26  75  46  29  ...  0.7  2.4  33.6    6    0  2.9
# 20      DeMar DeRozan  TOR   23  82  34  48  ...  0.3  2.1  28.3    0    0 -1.4
# 21           JR Smith  NYK   27  80  53  27  ...  0.3  2.8  31.5    8    0  3.7
# 22      Blake Griffin  LAC   24  80  55  25  ...  0.6  2.9  36.7   28    1  4.8
# 23       Al Jefferson  UTA   28  78  41  37  ...  1.1  2.2  37.2   37    0 -2.0
# 24         Tim Duncan  SAS   37  69  50  19  ...  2.7  1.7  41.7   36    0  6.7
#
# [25 rows x 29 columns]

# %%
top_players['TEAM'].nunique() # there is at least one player from every team in the top 100
# Out:
# 30

# %%
top_players['TEAM'].value_counts().mean()
# Out:
# 3.3333333333333335

# %%
top_10_team_dict = {
    'Miami Heat' : 'MIA',
    'Oklahoma City Thunder' : 'OKC',
    'San Antonio Spurs' : 'SAS',
    'Denver Nuggets' : 'DEN',
    'Los Angeles Clippers' : 'LAC',
    'Memphis Grizzlies' : 'MEM',
    'New York Knicks' : 'NYK',
    'Brooklyn Nets' : 'BKN',
    'Indiana Pacers' : 'IND',
    'Golden State Warriors' : 'GSW'
}

# %%
top_10_teams = df_2012[:10]
top_10_teams['TEAM_ABREV'] = top_10_teams['TEAM'].replace(top_10_team_dict)
top_10_teams
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                     TEAM  GP   W   L   WIN%  ...  BLKA    PF   PFD  +/-  TEAM_ABREV
# 0             Miami Heat  82  66  16  0.805  ...   3.2  18.7  20.4  7.9         MIA
# 1  Oklahoma City Thunder  82  60  22  0.732  ...   3.9  20.2  20.7  9.2         OKC
# 2      San Antonio Spurs  82  58  24  0.707  ...   4.9  17.4  19.1  6.4         SAS
# 3         Denver Nuggets  82  57  25  0.695  ...   6.8  20.5  21.6  5.1         DEN
# 4   Los Angeles Clippers  82  56  26  0.683  ...   4.1  20.9  20.9  6.5         LAC
# 5      Memphis Grizzlies  82  56  26  0.683  ...   5.5  20.2  20.0  4.1         MEM
# 6        New York Knicks  82  54  28  0.659  ...   4.0  20.1  19.2  4.2         NYK
# 7          Brooklyn Nets  82  49  33  0.598  ...   4.8  18.3  21.4  1.8         BKN
# 8         Indiana Pacers  81  49  32  0.605  ...   5.7  20.0  21.9  4.0         IND
# 9  Golden State Warriors  82  47  35  0.573  ...   4.9  21.4  19.2  0.9         GSW
#
# [10 rows x 28 columns]

# %%
top_100_player_dict = top_players['TEAM'].value_counts().to_dict()
top_10_teams['TOP_PLAYER_COUNT'] = top_10_teams['TEAM_ABREV'].replace(top_100_player_dict)
top_10_teams
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                     TEAM  GP   W   L  ...   PFD  +/-  TEAM_ABREV  TOP_PLAYER_COUNT
# 0             Miami Heat  82  66  16  ...  20.4  7.9         MIA                 3
# 1  Oklahoma City Thunder  82  60  22  ...  20.7  9.2         OKC                 4
# 2      San Antonio Spurs  82  58  24  ...  19.1  6.4         SAS                 2
# 3         Denver Nuggets  82  57  25  ...  21.6  5.1         DEN                 4
# 4   Los Angeles Clippers  82  56  26  ...  20.9  6.5         LAC                 3
# 5      Memphis Grizzlies  82  56  26  ...  20.0  4.1         MEM                 3
# 6        New York Knicks  82  54  28  ...  19.2  4.2         NYK                 4
# 7          Brooklyn Nets  82  49  33  ...  21.4  1.8         BKN                 3
# 8         Indiana Pacers  81  49  32  ...  21.9  4.0         IND                 3
# 9  Golden State Warriors  82  47  35  ...  19.2  0.9         GSW                 4
#
# [10 rows x 29 columns]

# %%
# There isn't much difference between the league average of top players per team, and the distribution of the top players per top team
# This doesn't take into account 'how good' each player is though
# Maybe we should be more exclusive to our list, and look at the players specifically
print('Top_100_players_per_team_MEAN = ' + str(top_players['TEAM'].value_counts().mean()))
print('Top_players_per_top_10_teams_MEAN = ' + str(top_10_teams['TOP_PLAYER_COUNT'].mean()))
# Out:
# Top_100_players_per_team_MEAN = 3.3333333333333335
# Top_players_per_top_10_teams_MEAN = 3.3

# %%
# top_10_teams = df_2012[:10]
# top_10_teams['TEAM_ABREV'] = top_10_teams['TEAM'].replace(top_10_team_dict)
# top_10_teams

# %%
top_10_teams = df_2012[:10]
top_10_teams['TEAM_ABREV'] = top_10_teams['TEAM'].replace(top_10_team_dict)
top_10_teams
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                     TEAM  GP   W   L   WIN%  ...  BLKA    PF   PFD  +/-  TEAM_ABREV
# 0             Miami Heat  82  66  16  0.805  ...   3.2  18.7  20.4  7.9         MIA
# 1  Oklahoma City Thunder  82  60  22  0.732  ...   3.9  20.2  20.7  9.2         OKC
# 2      San Antonio Spurs  82  58  24  0.707  ...   4.9  17.4  19.1  6.4         SAS
# 3         Denver Nuggets  82  57  25  0.695  ...   6.8  20.5  21.6  5.1         DEN
# 4   Los Angeles Clippers  82  56  26  0.683  ...   4.1  20.9  20.9  6.5         LAC
# 5      Memphis Grizzlies  82  56  26  0.683  ...   5.5  20.2  20.0  4.1         MEM
# 6        New York Knicks  82  54  28  0.659  ...   4.0  20.1  19.2  4.2         NYK
# 7          Brooklyn Nets  82  49  33  0.598  ...   4.8  18.3  21.4  1.8         BKN
# 8         Indiana Pacers  81  49  32  0.605  ...   5.7  20.0  21.9  4.0         IND
# 9  Golden State Warriors  82  47  35  0.573  ...   4.9  21.4  19.2  0.9         GSW
#
# [10 rows x 28 columns]

# %%
top_20_player_dict = top_players[:20]['TEAM'].value_counts().to_dict()
top_10_teams['TOP_PLAYER_COUNT'] = top_10_teams['TEAM_ABREV'].replace(top_20_player_dict)
top_10_teams

# This shows us a little more information, the top 3 teams have the top 5 players in the league.
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                     TEAM  GP   W   L  ...   PFD  +/-  TEAM_ABREV  TOP_PLAYER_COUNT
# 0             Miami Heat  82  66  16  ...  20.4  7.9         MIA                 2
# 1  Oklahoma City Thunder  82  60  22  ...  20.7  9.2         OKC                 2
# 2      San Antonio Spurs  82  58  24  ...  19.1  6.4         SAS                 1
# 3         Denver Nuggets  82  57  25  ...  21.6  5.1         DEN               DEN
# 4   Los Angeles Clippers  82  56  26  ...  20.9  6.5         LAC               LAC
# 5      Memphis Grizzlies  82  56  26  ...  20.0  4.1         MEM               MEM
# 6        New York Knicks  82  54  28  ...  19.2  4.2         NYK                 1
# 7          Brooklyn Nets  82  49  33  ...  21.4  1.8         BKN                 2
# 8         Indiana Pacers  81  49  32  ...  21.9  4.0         IND               IND
# 9  Golden State Warriors  82  47  35  ...  19.2  0.9         GSW                 2
#
# [10 rows x 29 columns]

# %%
print('-- THE TOP 10 TEAMS --')
for k, v in enumerate(top_10_team_dict):
  print(f'{k+1}: {top_10_team_dict[v]}')
# Out:
# -- THE TOP 10 TEAMS --
# 1: MIA
# 2: OKC
# 3: SAS
# 4: DEN
# 5: LAC
# 6: MEM
# 7: NYK
# 8: BKN
# 9: IND
# 10: GSW

# %%
df_filter = top_players.TEAM == 'MIA'
print(top_players[df_filter]['PTS'].sum()/top_10_teams.iloc[0].PTS) # The top 3 Miami players contribute to 63% of the team's average points per game
# Out:
# 0.6277939747327501

# %%
top_players[:10]
# Out:
#               PLAYER TEAM  AGE  GP   W   L  ...  BLK   PF    FP  DD2  TD3  +/-
# 0    Carmelo Anthony  NYK   29  67  47  20  ...  0.5  3.1  41.9   10    0  4.6
# 1       Kevin Durant  OKC   24  81  60  21  ...  1.3  1.8  49.3   19    3  8.9
# 2        Kobe Bryant  LAL   34  78  42  36  ...  0.3  2.2  44.4   16    2  1.8
# 3       LeBron James  MIA   28  76  61  15  ...  0.9  1.4  52.1   36    4  9.5
# 4       James Harden  HOU   23  78  43  35  ...  0.5  2.3  43.7    9    1  2.5
# 5  Russell Westbrook  OKC   24  82  60  22  ...  0.3  2.3  43.4   23    1  7.7
# 6      Stephen Curry  GSW   25  78  45  33  ...  0.2  2.5  40.3   15    0  1.7
# 7       Kyrie Irving  CLE   21  59  19  40  ...  0.4  2.5  38.1    4    0 -3.0
# 8        Dwyane Wade  MIA   31  69  55  14  ...  0.8  2.0  40.0    4    0  8.3
# 9  LaMarcus Aldridge  POR   27  74  32  42  ...  1.2  2.5  40.1   38    0 -0.3
#
# [10 rows x 29 columns]

# %%
plt.hist(top_players['PTS'], bins='auto')
plt.grid(color='whitesmoke', axis='x', linestyle=':')
plt.xlabel('PTS', fontsize = 16)
plt.ylabel("Count", fontsize = 16)
ax = plt.gca()
ax.set_facecolor('whitesmoke')


for i in range(10):
  if top_players.iloc[i].TEAM in top_10_team_dict.values():
    #print(top_players.iloc[i].TEAM)
    line = plt.axvline(top_players.iloc[i].PTS, 0, 30, c='dimgray', linewidth=3)
  else:
    line = plt.axvline(top_players.iloc[i].PTS, 0, 30, c='darkorange', linewidth=3)
